# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
print(math.ceil(4.956)) # It returns the upper bond value
print(math.floor(4.25)) # It returns the lower bond value
print(math.factorial(5)) # It returns factorial of a number
print(math.gcd(10,5,2)) # It returns the GCD value
print(math.lcm(45,5))
print(math.log10(2))
print(math.log10(4))
print(math.log2(4))
print(math.pi)
# Out:
# 5
# 4
# 120
# 1
# 45
# 0.3010299956639812
# 0.6020599913279624
# 2.0
# 3.141592653589793

# %%
import random
print(random.random()) # This Function returns the value in between 0 to 1
print(random.randint(1,10)) # This function generates random number between 'a' and 'b'
print(random.choice(['A',1,2,3,4,5,6,7,8,9,'J','Q','K'])) # It return random items
print(random.choices(['A',1,2,3,4,5,6,7,8,9,'J','Q','K'],k=3))
arr = ['A',1,2,3,4,5,6,7,8,9,'J','Q','K']
random.shuffle(arr)
print(arr)
# Out:
# 0.8681416143024602
# 10
# 4
# ['A', 'Q', 'A']
# ['A', 'K', 2, 4, 6, 5, 3, 9, 1, 7, 'Q', 8, 'J']

# %%
# who will reach top in less steps
import random
steps = rolls = 0
while True :
    input("To roll dice for that click enter button")
    dice_val = random.randint(1,6)
    rolls += 1
    print("Current dice value:", dice_val)
    if steps + dice_val <=100:
        steps += dice_val
    if steps == 100:
        print(f"Your reached TOP in {rolls}rolls")
        break
    print(f"For {rolls} rolls your at {steps} position")
# Out:
# To roll dice for that click enter button
# Current dice value: 5
# For 1 rolls your at 5 position
# To roll dice for that click enter button
# Current dice value: 2
# For 2 rolls your at 7 position
# To roll dice for that click enter button
# Current dice value: 2
# For 3 rolls your at 9 position
# To roll dice for that click enter button
# Current dice value: 2
# For 4 rolls your at 11 position
# To roll dice for that click enter button
# Current dice value: 6
# For 5 rolls your at 17 position
# To roll dice for that click enter button
# Current dice value: 4
# For 6 rolls your at 21 position
# To roll dice for that click enter button
# Current dice value: 4
# For 7 rolls your at 25 position
# To roll dice for that click enter button
# Current dice value: 4
# For 8 rolls your at 29 position
# To roll dice for that click enter button
# Current dice value: 3
# For 9 rolls your at 32 position
# To roll dice for that click enter button
# Current dice value: 5
# For 10 rolls your at 37 position
# To roll dice for that click enter button
# Current dice value: 6
# For 11 rolls your at 43 position
# To roll dice for that click enter button
# Current dice value: 4
# For 12 rolls your at 47 position
# To roll dice for that click enter button
# Current dice value: 2
# For 13 rolls your at 49 position
# To roll dice for that click enter button
# Current dice value: 2
# For 14 rolls your at 51 position
# To roll dice for that click enter button
# Current dice value: 3
# For 15 rolls your at 54 position
# To roll dice for that click enter button
# Current dice value: 6
# For 16 rolls your at 60 position
# To roll dice for that click enter button
# Current dice value: 5
# For 17 rolls your at 65 position
# To roll dice for that click enter button
# Current dice value: 2
# For 18 rolls your at 67 position
# To roll dice for that click enter button
# Current dice value: 4
# For 19 rolls your at 71 position
# To roll dice for that click enter button
# Current dice value: 3
# For 20 rolls your at 74 position
# To roll dice for that click enter button
# Current dice value: 1
# For 21 rolls your at 75 position
# To roll dice for that click enter button
# Current dice value: 3
# For 22 rolls your at 78 position
# To roll dice for that click enter button
# Current dice value: 4
# For 23 rolls your at 82 position
# To roll dice for that click enter button
# Current dice value: 4
# For 24 rolls your at 86 position
# To roll dice for that click enter button
# Current dice value: 4
# For 25 rolls your at 90 position
# To roll dice for that click enter button
# Current dice value: 3
# For 26 rolls your at 93 position
# To roll dice for that click enter button
# Current dice value: 1
# For 27 rolls your at 94 position
# To roll dice for that click enter button
# Current dice value: 5
# For 28 rolls your at 99 position
# To roll dice for that click enter button
# Current dice value: 3
# For 29 rolls your at 99 position
# To roll dice for that click enter button
# Current dice value: 4
# For 30 rolls your at 99 position
# To roll dice for that click enter button
# Current dice value: 1
# Your reached TOP in 31rolls

# %%
import sys
print(sys.version) # It returns the python version
print(sys.getsizeof([]))
print(sys.getsizeof(()))
print(sys.getsizeof(10000000000))
# Out:
# 3.13.14 (tags/v3.13.14:fd17997, Jun 10 2026, 13:03:48) [MSC v.1944 64 bit (AMD64)]
# 56
# 40
# 32
